# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# # **Load the data**

# %%
sales = pd.read_csv(r"C:\Users\rocky\Desktop\ForeSight\data\raw\sales_daily.csv", 
                    parse_dates=["Date"])
inv   = pd.read_csv(r"C:\Users\rocky\Desktop\ForeSight\data\raw\inventory_snapshots.csv",
                    parse_dates=["Snapshot_Date"])
sku   = pd.read_csv(r"C:\Users\rocky\Desktop\ForeSight\data\raw\sku_master.csv", 
                    parse_dates=["Launch_Date"])
cal   = pd.read_csv(r"C:\Users\rocky\Desktop\ForeSight\data\raw\calendar.csv", 
                    parse_dates=["date"])

# %% [markdown]
# # **Sales Checks**

# %%
sales.shape
# Out:
# (36550, 6)

# %%
print(sales.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36550 entries, 0 to 36549
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        36550 non-null  datetime64[ns]
#  1   SKU         36550 non-null  object
#  2   Units_Sold  36550 non-null  int64
#  3   Revenue     36550 non-null  float64
#  4   Price       36550 non-null  float64
#  5   Promotion   36550 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(1)
# memory usage: 1.7+ MB
# None

# %%
print(sales.head())
# Out:
#         Date     SKU  Units_Sold    Revenue    Price  Promotion
# 0 2024-01-01  SKU001           5   18320.25  3664.05          0
# 1 2024-01-01  SKU002          15   57085.35  3805.69          0
# 2 2024-01-01  SKU003           5   40391.15  8078.23          0
# 3 2024-01-01  SKU004           5   34307.85  6861.57          0
# 4 2024-01-01  SKU005          12  113918.64  9493.22          0

# %%
sales.dtypes
# Out:
# Date          datetime64[ns]
# SKU                   object
# Units_Sold             int64
# Revenue              float64
# Price                float64
# Promotion              int64
# dtype: object

# %% [markdown]
# # **Check for NULL**

# %%
sales.isnull().sum()
# Out:
# Date          0
# SKU           0
# Units_Sold    0
# Revenue       0
# Price         0
# Promotion     0
# dtype: int64

# %%
sales.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Hence no Null or Duplicated values in sales data**

# %% [markdown]
# # **Inventory Checks**

# %%
inv.shape
# Out:
# (4800, 8)

# %%
inv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4800 entries, 0 to 4799
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Snapshot_Date    4800 non-null   datetime64[ns]
#  1   SKU              4800 non-null   object
#  2   Current_Stock    4800 non-null   int64
#  3   On_Order         4800 non-null   int64
#  4   Lead_Time_Days   4800 non-null   int64
#  5   Safety_Stock     4800 non-null   int64
#  6   Reorder_Point    4800 non-null   int64
#  7   Inventory_Value  4800 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(1)
# memory usage: 300.1+ KB

# %%
inv.dtypes
# Out:
# Snapshot_Date      datetime64[ns]
# SKU                        object
# Current_Stock               int64
# On_Order                    int64
# Lead_Time_Days              int64
# Safety_Stock                int64
# Reorder_Point               int64
# Inventory_Value           float64
# dtype: object

# %%
print(inv.head())
# Out:
#   Snapshot_Date     SKU  Current_Stock  On_Order  Lead_Time_Days  \
# 0    2024-01-01  SKU001             16        23              11
# 1    2024-01-01  SKU002             29        12               4
# 2    2024-01-01  SKU003             34        23              14
# 3    2024-01-01  SKU004             34         4               7
# 4    2024-01-01  SKU005             23         5               5
#
#    Safety_Stock  Reorder_Point  Inventory_Value
# 0             7             18         58420.96
# 1             5             10        163983.40
# 2             6             20        209060.22
# 3             5             12         42257.92
# 4             6             11        170945.89

# %% [markdown]
# # **Check for NULL and Duplicated values**

# %%
inv.isnull().sum()
# Out:
# Snapshot_Date      0
# SKU                0
# Current_Stock      0
# On_Order           0
# Lead_Time_Days     0
# Safety_Stock       0
# Reorder_Point      0
# Inventory_Value    0
# dtype: int64

# %%
inv.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Hence no Null or Duplicated values in sales data**

# %% [markdown]
# # **Sku Check**

# %%
sku.shape
# Out:
# (50, 8)

# %%
sku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SKU                    50 non-null     object
#  1   Product_Name           50 non-null     object
#  2   Category               50 non-null     object
#  3   Subcategory            50 non-null     object
#  4   Launch_Date            50 non-null     datetime64[ns]
#  5   Cost_Price             50 non-null     float64
#  6   Selling_Price          50 non-null     float64
#  7   Gross_Margin_Per_Unit  50 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 3.3+ KB

# %%
sku.dtypes
# Out:
# SKU                              object
# Product_Name                     object
# Category                         object
# Subcategory                      object
# Launch_Date              datetime64[ns]
# Cost_Price                      float64
# Selling_Price                   float64
# Gross_Margin_Per_Unit           float64
# dtype: object

# %%
print(sku.head())
# Out:
#       SKU Product_Name    Category Subcategory Launch_Date  Cost_Price  \
# 0  SKU001  Product 001   Furniture       Chair  2022-04-09     1758.45
# 1  SKU002  Product 002  Home Decor       Table  2024-05-01     3867.09
# 2  SKU003  Product 003     Kitchen     Cushion  2023-12-22      589.48
# 3  SKU004  Product 004    Lighting    Cookware  2023-04-28     1445.74
# 4  SKU005  Product 005     Storage        Lamp  2023-04-22     5543.63
#
#    Selling_Price  Gross_Margin_Per_Unit
# 0        3664.05                1905.60
# 1        3805.69                 -61.40
# 2        8078.23                7488.75
# 3        6861.57                5415.83
# 4        9493.22                3949.59

# %% [markdown]
# # **Check for Null or Duplicated values**

# %%
sku.isnull().sum()
# Out:
# SKU                      0
# Product_Name             0
# Category                 0
# Subcategory              0
# Launch_Date              0
# Cost_Price               0
# Selling_Price            0
# Gross_Margin_Per_Unit    0
# dtype: int64

# %%
sku.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **No Null or duplicated values in the sku data**

# %% [markdown]
# # **Calender checks**

# %%
cal.shape
# Out:
# (731, 11)

# %%
cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             731 non-null    datetime64[ns]
#  1   year             731 non-null    int64
#  2   month            731 non-null    int64
#  3   quarter          731 non-null    object
#  4   week             731 non-null    int64
#  5   day_of_week      731 non-null    object
#  6   is_weekend       731 non-null    int64
#  7   season           731 non-null    object
#  8   holiday          8 non-null      object
#  9   is_holiday       731 non-null    int64
#  10  promotion_event  75 non-null     object
# dtypes: datetime64[ns](1), int64(5), object(5)
# memory usage: 62.9+ KB

# %%
cal.dtypes
# Out:
# date               datetime64[ns]
# year                        int64
# month                       int64
# quarter                    object
# week                        int64
# day_of_week                object
# is_weekend                  int64
# season                     object
# holiday                    object
# is_holiday                  int64
# promotion_event            object
# dtype: object

# %%
print(cal.head())
# Out:
#         date  year  month quarter  week day_of_week  is_weekend  season  \
# 0 2024-01-01  2024      1      Q1     1      Monday           0  Winter
# 1 2024-01-02  2024      1      Q1     1     Tuesday           0  Winter
# 2 2024-01-03  2024      1      Q1     1   Wednesday           0  Winter
# 3 2024-01-04  2024      1      Q1     1    Thursday           0  Winter
# 4 2024-01-05  2024      1      Q1     1      Friday           0  Winter
#
#   holiday  is_holiday promotion_event
# 0     NaN           0             NaN
# 1     NaN           0             NaN
# 2     NaN           0             NaN
# 3     NaN           0             NaN
# 4     NaN           0             NaN

# %% [markdown]
# # **Check for Null or Duplicated values**

# %%
cal.isnull().sum()
# Out:
# date                 0
# year                 0
# month                0
# quarter              0
# week                 0
# day_of_week          0
# is_weekend           0
# season               0
# holiday            723
# is_holiday           0
# promotion_event    656
# dtype: int64

# %%
cal.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **There are no duplicted but there are null values**

# %% [markdown]
# # **Handling the Null Values**

# %%
cal['holiday'].fillna("None",inplace=True)
# Out:
# E:\temp\ipykernel_23336\3592985589.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cal['holiday'].fillna("None",inplace=True)

# %%
cal['promotion_event'].fillna("None",inplace = True)
# Out:
# E:\temp\ipykernel_23336\1698914493.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cal['promotion_event'].fillna("None",inplace = True)

# %%
cal.isnull().sum()
# Out:
# date               0
# year               0
# month              0
# quarter            0
# week               0
# day_of_week        0
# is_weekend         0
# season             0
# holiday            0
# is_holiday         0
# promotion_event    0
# dtype: int64

# %% [markdown]
# **Done with the Basic checks and cleaning**

# %% [markdown]
# # **Check for the duplicated keys**

# %%
dupe_count_sales = sales.duplicated(subset=["Date", "SKU"]).sum()
dupe_count_inv   = inv.duplicated(subset=["Snapshot_Date", "SKU"]).sum()

print(dupe_count_sales, dupe_count_inv)
# Out:
# 0 0

# %%
if dupe_count_sales:
    # look at them before deciding — are they true duplicates, or same Date+SKU
    print(sales[sales.duplicated(subset=["Date", "SKU"], keep=False)])
    sales = sales.drop_duplicates(subset=["Date", "SKU"], keep="first")

# %% [markdown]
# # **Check SKU overlap across files before merging**

# %%
sku_ids   = set(sku["SKU"])
sales_ids = set(sales["SKU"])
inv_ids   = set(inv["SKU"])

print("sales SKUs not in sku_master:", sales_ids - sku_ids)
print("inventory SKUs not in sku_master:", inv_ids - sku_ids)
# everything in the left set that's not in the right set so use -
# Out:
# sales SKUs not in sku_master: set()
# ...

# %%
print(len(sales_ids - sku_ids))   # 0 — sales SKUs all exist in sku_master
print(len(inv_ids - sku_ids))     # 150 — inventory has 150 orphans
# Out:
# 0
# 150

# %%
orphans = sorted(inv_ids - sku_ids)

inv_excluded = inv[inv["SKU"].isin(orphans)]       # keep these — don't just discard
inv_clean    = inv[~inv["SKU"].isin(orphans)]       # only SKUs sku_master can enrich

# %% [markdown]
# # **Build the sales fact table**

# %%
fact_sales = (
    sales
    .merge(cal, left_on="Date", right_on="date", how="left")
    .merge(sku, on="SKU", how="left")
)
fact_sales = fact_sales.drop(columns=["date"])

# %%
print(fact_sales.shape)                 # (36550, 23) — same row count as sales, more columns
print(fact_sales.isnull().sum().sum())  # 0 - every row matched both calendar and sku_master
# Out:
# (36550, 23)
# 0

# %% [markdown]
# # **Build the Inventory fact table**

# %%
sku_ids = set(sku["SKU"])
orphans = sorted(set(inv["SKU"]) - sku_ids)

inv_excluded = inv[inv["SKU"].isin(orphans)]     # save separately — don't discard
inv_clean    = inv[~inv["SKU"].isin(orphans)]    # only SKUs sku_master can enrich

fact_inventory = inv_clean.merge(sku, on="SKU", how="left")

# %%
print(fact_inventory.shape)
print(inv_excluded.shape)
print(fact_inventory.isnull().sum().sum())
# Out:
# (1200, 15)
# (3600, 8)
# 0

# %% [markdown]
# (1200, 15) — inventory rows for the 50 matched SKUs only
#
# (3600, 8)  — the orphan rows, untouched, saved for review
#
# 0 — no NaNs snuck through

# %% [markdown]
# # **Log Lines**

# %%
log_lines = []

def log(msg):
    print(msg)
    log_lines.append(msg)

log(f"Loaded: sales={sales.shape}, inventory={inv.shape}, sku={sku.shape}, calendar={cal.shape}")
log(f"Duplicate keys: sales={dupe_count_sales}, inventory={dupe_count_inv}")
log(f"Inventory SKUs missing from sku_master: {len(orphans)}")
# Out:
# Loaded: sales=(36550, 6), inventory=(4800, 8), sku=(50, 8), calendar=(731, 11)
# Duplicate keys: sales=0, inventory=0
# Inventory SKUs missing from sku_master: 150

# %% [markdown]
# # **Final save**

# %%
OUT = Path("Processed")
OUT.mkdir(exist_ok=True)

fact_sales.to_csv(OUT / "fact_sales_daily.csv", index=False)
fact_inventory.to_csv(OUT / "fact_inventory.csv", index=False)
inv_excluded.to_csv(OUT / "excluded_inventory_skus.csv", index=False)
sku.to_csv(OUT / "dim_sku.csv", index=False)
