# %% [markdown]
# # **Perform EDA And Data quality checks**

# %%
import pandas as pd
import matplotlib.pyplot as plt

fact_sales = pd.read_csv(r"C:\Users\rocky\Desktop\ForeSight\data\processed\fact_sales_daily.csv", 
                         parse_dates=["Date"])
fact_inv   = pd.read_csv(r"C:\Users\rocky\Desktop\ForeSight\data\processed\fact_inventory.csv", 
                         parse_dates=["Snapshot_Date"])

# %%
fact_sales.isnull().sum()
# Out:
# Date                         0
# SKU                          0
# Units_Sold                   0
# Revenue                      0
# Price                        0
# Promotion                    0
# year                         0
# month                        0
# quarter                      0
# week                         0
# day_of_week                  0
# is_weekend                   0
# season                       0
# holiday                  36150
# is_holiday                   0
# promotion_event          32800
# Product_Name                 0
# Category                     0
# Subcategory                  0
# Launch_Date                  0
# Cost_Price                   0
# Selling_Price                0
# Gross_Margin_Per_Unit        0
# dtype: int64

# %%
# Handle missing categorical event values

fact_sales['holiday'] = fact_sales['holiday'].fillna("None")
fact_sales['promotion_event'] = fact_sales['promotion_event'].fillna("None")

# %%
fact_sales.isnull().sum()
# Out:
# Date                     0
# SKU                      0
# Units_Sold               0
# Revenue                  0
# Price                    0
# Promotion                0
# year                     0
# month                    0
# quarter                  0
# week                     0
# day_of_week              0
# is_weekend               0
# season                   0
# holiday                  0
# is_holiday               0
# promotion_event          0
# Product_Name             0
# Category                 0
# Subcategory              0
# Launch_Date              0
# Cost_Price               0
# Selling_Price            0
# Gross_Margin_Per_Unit    0
# dtype: int64

# %% [markdown]
# **Quick stats overview**

# %%
fact_sales.describe()
# Out:
#                       Date    Units_Sold       Revenue         Price  \
# count                36550  36550.000000   36550.00000  36550.000000
# mean   2024-12-31 00:00:00     14.003010   84707.43385   5892.663800
# min    2024-01-01 00:00:00      0.000000       0.00000    663.460000
# 25%    2024-07-01 00:00:00      7.000000   27643.70000   3484.090000
# 50%    2024-12-31 00:00:00     13.000000   56125.90000   5649.795000
# 75%    2025-07-02 00:00:00     20.000000  127954.32000   8516.600000
# max    2025-12-31 00:00:00     56.000000  546977.00000  11642.450000
# std                    NaN      8.467305   76534.63044   3138.775609
#
#           Promotion          year         month          week    is_weekend  \
# count  36550.000000  36550.000000  36550.000000  36550.000000  36550.000000
# mean       0.102599   2024.499316      6.519836     26.395349      0.284542
# min        0.000000   2024.000000      1.000000      1.000000      0.000000
# 25%        0.000000   2024.000000      4.000000     13.000000      0.000000
# 50%        0.000000   2024.000000      7.000000     26.000000      0.000000
# 75%        0.000000   2025.000000     10.000000     39.000000      1.000000
# max        1.000000   2025.000000     12.000000     52.000000      1.000000
# std        0.303439      0.500006      3.449598     15.066169      0.451202
#
#          is_holiday    Cost_Price  Selling_Price  Gross_Margin_Per_Unit
# count  36550.000000  36550.000000   36550.000000            36550.00000
# mean       0.010944   3770.729400    5892.663800             2121.93440
# min        0.000000    307.060000     663.460000            -5484.32000
# 25%        0.000000   1913.030000    3484.090000             -681.48000
# 50%        0.000000   3836.845000    5649.795000             1790.02500
# 75%        0.000000   5539.340000    8516.600000             4923.44000
# max        1.000000   7748.200000   11642.450000            10224.93000
# std        0.104041   2005.453732    3138.775609             3746.89606

# %% [markdown]
# ### Key Insights
# - Dataset contains **36,550 observations**.
# - Average daily demand is **14 units** per SKU.
# - Demand ranges from **0 to 56 units**, showing significant variation.
# - Revenue also varies substantially across observations.

# %% [markdown]
# **Sales Trend Overtime**

# %%
daily = fact_sales.groupby("Date")["Units_Sold"].sum()
daily.plot(figsize=(12,4), title="Total Units Sold Over Time")
plt.show()

# %% [markdown]
# ### Key Insights
# - Sales show clear fluctuations over time.
# - Demand patterns suggest the presence of **seasonality**.
# - Time-based features should therefore be considered for forecasting.

# %% [markdown]
# **Monthly/seasonal pattern**

# %%
fact_sales.groupby(fact_sales["Date"].dt.to_period("M"))["Units_Sold"].sum().plot(kind="bar", figsize=(12,4))
plt.show()

# %% [markdown]
# ### Key Insights
# - **March** shows the highest demand across the year.
# - **September–October** generally show lower demand.
# - The recurring pattern indicates strong **seasonality**.

# %% [markdown]
# **Holiday or No holiday sales Analysis**

# %%
fact_sales.groupby("is_holiday")["Units_Sold"].mean()
# Out:
# is_holiday
# 0    14.023402
# 1    12.160000
# Name: Units_Sold, dtype: float64

# %% [markdown]
# ### Key Insights
# - Average demand on regular days: **14.02 units**.
# - Average demand on holidays: **12.16 units**.
# - Holiday periods show slightly lower average demand in this dataset.

# %% [markdown]
# **Promotion or no promotion sales**

# %%
fact_sales['promotion_event'].unique()
# Out:
# array(['None', 'Seasonal Promotion'], dtype=object)

# %%
fact_sales.groupby("promotion_event")["Units_Sold"].mean().sort_values(ascending=False)
# Out:
# promotion_event
# Seasonal Promotion    18.613067
# None                  13.475945
# Name: Units_Sold, dtype: float64

# %% [markdown]
# ### Key Insights
#
# - The dataset contains a **Seasonal Promotion** event in addition to non-promotion observations.
# - Average units sold during the Seasonal Promotion period are approximately **18.61 units**.
# - Overall average demand is approximately **14.00 units**.
# - This represents roughly a **32.9% increase in average units sold** during the Seasonal Promotion period compared with the overall average.
# - Promotions therefore appear to be an important demand driver and should be incorporated into the forecasting model.
# - Promotional periods may also increase **stockout risk**, making advance inventory planning particularly important.

# %% [markdown]
# **Top categories by revenue**

# %%
fact_sales['Category'].unique()
# Out:
# array(['Furniture', 'Home Decor', 'Kitchen', 'Lighting', 'Storage'],
#       dtype=object)

# %%
fact_sales.groupby("Category")["Revenue"].sum().sort_values(ascending=False)
# Out:
# Category
# Home Decor    8.884681e+08
# Furniture     6.033905e+08
# Storage       5.819274e+08
# Kitchen       5.635346e+08
# Lighting      4.587362e+08
# Name: Revenue, dtype: float64

# %% [markdown]
# ### Key Insights
# - **Home Decor** generates the highest revenue.
# - **Lighting** generates the lowest revenue among the five categories.
# - Category performance varies considerably and should be considered in inventory planning.

# %% [markdown]
# **Top and Bottom SKU's**

# %%
fact_sales.groupby("SKU")["Units_Sold"].sum().sort_values(ascending=False).head(10)   # best sellers
# Out:
# SKU
# SKU012    19067
# SKU045    18612
# SKU018    18450
# SKU049    18373
# SKU037    18155
# SKU007    18129
# SKU027    17717
# SKU042    16616
# SKU026    16535
# SKU043    16276
# Name: Units_Sold, dtype: int64

# %%
fact_sales.groupby("SKU")["Units_Sold"].sum().sort_values().head(10)  # worst sellers
# Out:
# SKU
# SKU011    1951
# SKU025    1976
# SKU039    2300
# SKU015    2994
# SKU004    3380
# SKU030    3493
# SKU036    3508
# SKU028    4101
# SKU003    4214
# SKU050    4537
# Name: Units_Sold, dtype: int64

# %% [markdown]
# ### Key Insights
# - **SKU012** is the highest-selling SKU with **19,067 units**.
# - **SKU011** is the lowest-selling SKU with **1,951 units**.
# - Large differences in SKU demand support **SKU-level forecasting**.

# %% [markdown]
# **Margin sanity check**

# %%
fact_sales["Gross_Margin_Per_Unit"].describe()
# Out:
# count    36550.00000
# mean      2121.93440
# std       3746.89606
# min      -5484.32000
# 25%       -681.48000
# 50%       1790.02500
# 75%       4923.44000
# max      10224.93000
# Name: Gross_Margin_Per_Unit, dtype: float64

# %% [markdown]
# ### Key Insights
# - Average gross margin per unit is approximately **₹2,122**.
# - **11,696 observations** have negative gross margins.
# - Negative margins require further investigation before financial-impact analysis.

# %% [markdown]
# **Zero-sales days - these are real no demand days**

# %%
(fact_sales['Units_Sold']==0).sum()
# Out:
# 202

# %%
# are zero-sales days spread across many SKUs, or concentrated in a few?
fact_sales[fact_sales["Units_Sold"] == 0]["SKU"].value_counts().head(10)
# Out:
# SKU
# SKU025    58
# SKU011    55
# SKU039    36
# SKU015    15
# SKU004    13
# SKU036     8
# SKU030     7
# SKU003     4
# SKU028     2
# SKU048     1
# Name: count, dtype: int64

# %%
# are they clustered on specific dates (data gap) or scattered (real no-demand)?
fact_sales[fact_sales["Units_Sold"] == 0]["Date"].value_counts().head(10)
# Out:
# Date
# 2024-09-23    4
# 2025-11-25    3
# 2025-04-25    2
# 2024-07-23    2
# 2025-10-22    2
# 2025-10-21    2
# 2024-11-25    2
# 2025-10-09    2
# 2024-06-17    2
# 2024-07-17    2
# Name: count, dtype: int64

# %% [markdown]
# **Negative margin — how big is this actually?**

# %%
(fact_sales["Gross_Margin_Per_Unit"] < 0).sum()
# Out:
# 11696

# %% [markdown]
# **Negative margin rate by category — is it spread evenly or concentrated?**

# %%
fact_sales.groupby("Category")["Gross_Margin_Per_Unit"] \
    .apply(lambda x: (x < 0).mean() * 100).sort_values(ascending=False)
# Out:
# Category
# Kitchen       60.0
# Home Decor    30.0
# Storage       30.0
# Furniture     20.0
# Lighting      20.0
# Name: Gross_Margin_Per_Unit, dtype: float64

# %% [markdown]
# **Sanity-check Revenue and Price aren't negative (should be 0)**

# %%
(fact_sales["Revenue"] < 0).sum(), (fact_sales["Price"] < 0).sum()
# Out:
# (0, 0)

# %% [markdown]
# ### Key Insights
#
# The EDA confirms that the dataset is structurally sound, with **202 zero-sales observations** and **11,696 negative-margin observations** requiring further investigation. No negative Revenue or Price values were found, and the main demand patterns show meaningful variation across SKUs, supporting **SKU-level forecasting and inventory risk analysis**.

# %% [markdown]
# # Overall EDA Conclusions
#
# The exploratory analysis reveals several important demand and inventory patterns:
#
# 1. **Demand is highly variable** across SKU-date observations, making SKU-level forecasting more appropriate than using aggregate averages.
# 2. **Strong seasonality is present**, with March consistently representing a major demand peak and September–October representing a recurring low-demand period.
# 3. **Promotional activity has a significant demand impact**, with Seasonal Promotion observations showing approximately 33% higher average unit sales than the overall average.
# 4. **Holiday periods show lower average demand** in this dataset, so holiday effects should be modeled rather than assumed to increase sales.
# 5. **Revenue is concentrated to some extent in Home Decor**, which contributes approximately 28.7% of total revenue.
# 6. **SKU demand varies substantially**, creating different replenishment priorities for high-velocity and low-velocity products.
# 7. **Negative gross margins are present** and require further data-quality/business-rule investigation before financial impact calculations are finalized.
#
# ### Modeling Implications
#
# These findings support using:
#
# - **Seasonality and calendar features** for demand forecasting.
# - **Promotion indicators** as demand drivers.
# - **SKU-level forecasting** rather than only aggregate forecasting.
# - **Historical demand patterns** to identify potential stockout and overstock periods.
# - **Revenue and margin information** when translating inventory risks into financial impact.
#
# The EDA therefore provides a strong foundation for the next stage: **D3 demand forecasting and D4 stockout/overstock risk scoring**.
